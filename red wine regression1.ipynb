# %% [markdown]
# ##Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/datasets_4458_8204_winequality-red.csv')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0               7.4             0.700         0.00  ...       0.56      9.4        5
# 1               7.8             0.880         0.00  ...       0.68      9.8        5
# 2               7.8             0.760         0.04  ...       0.65      9.8        5
# 3              11.2             0.280         0.56  ...       0.58      9.8        6
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1594            6.2             0.600         0.08  ...       0.58     10.5        5
# 1595            5.9             0.550         0.10  ...       0.76     11.2        6
# 1596            6.3             0.510         0.13  ...       0.75     11.0        6
# 1597            5.9             0.645         0.12  ...       0.71     10.2        5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
data['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %% [markdown]
# ##Separate Features and Target

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:, -1].values

# %% [markdown]
# ##Splitting Data into Train and Test sets

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ##Standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
ttrain = y_train.reshape(len(y_train), 1)
ttest = y_test.reshape(len(y_test), 1)

# %%
x_sc = StandardScaler()
y_sc = StandardScaler()

# %%
xdt_train = x_sc.fit_transform(x_train)
ydt_train = y_sc.fit_transform(ttrain)

# %%
xdt_test = x_sc.transform(x_test)
ydt_test = y_sc.transform(ttest)

# %%
xdt_train
# Out:
# array([[-0.54093053, -0.18247677, -0.02815116, ...,  0.27139469,
#         -0.18305368,  1.47565337],
#        [-1.28191355,  0.38434238, -1.35412642, ...,  1.37809665,
#         -0.58317076,  0.91317161],
#        [-0.36993445,  0.10093281, -0.0791502 , ..., -0.31450634,
#         -0.41169201, -0.68052669],
#        ...,
#        [-0.76892531,  0.55438812, -0.99713308, ...,  1.11769619,
#         -0.75464951, -1.33675541],
#        [ 0.48504596,  0.61107004, -0.33414545, ..., -0.18430611,
#         -0.46885159, -0.77427365],
#        [-0.31293575,  0.15761472, -1.40512547, ..., -0.31450634,
#         -0.12589409, -0.96176757]])

# %%
ydt_train
# Out:
# array([[ 0.45726087],
#        [-0.78443053],
#        [-0.78443053],
#        ...,
#        [-0.78443053],
#        [-0.78443053],
#        [ 0.45726087]])

# %% [markdown]
# ##Train on different algorithms

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import PolynomialFeatures

# %%
r_reg = RandomForestRegressor()
l_reg = LinearRegression()
d_reg = DecisionTreeRegressor()
s_reg = SVR()
p_reg = LinearRegression()

# %%
x_pol = PolynomialFeatures(degree=2)
x_pol = x_pol.fit_transform(xdt_train)

# %%
temp = PolynomialFeatures(degree=2)
temp = temp.fit_transform(xdt_test)

# %%
r_reg.fit(xdt_train, ydt_train)
l_reg.fit(xdt_train, ydt_train)
d_reg.fit(xdt_train, ydt_train)
s_reg.fit(xdt_train, ydt_train)
p_reg.fit(x_pol, ydt_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
r_pred = r_reg.predict(xdt_test)
l_pred = l_reg.predict(xdt_test)
d_pred = d_reg.predict(xdt_test)
s_pred = s_reg.predict(xdt_test)
p_pred = p_reg.predict(temp)

# %% [markdown]
# ##Result

# %%
from sklearn.metrics import r2_score

# %%
r = r2_score(ydt_test, r_pred)
l = r2_score(ydt_test, l_pred)
d = r2_score(ydt_test, d_pred)
s = r2_score(ydt_test, s_pred)
p = r2_score(ydt_test, p_pred)

# %%
print('Random Forest: ' + str(r) + '\nLinear Regression: ' + str(l) + '\nDecision Tree: ' + str(d) + '\nSVR: ' + str(s)  + '\nPolynomial Features: ' + str(p))
# Out:
# Random Forest: 0.5298523801820614
# Linear Regression: 0.42778576090157816
# Decision Tree: 0.12939896174943732
# SVR: 0.4439865614874138
# Polynomial Features: 0.427845036365492

# %%
cond = [(data['quality']>=7.5), (data['quality']<7.5)]
gb = ['Good', 'Bad']
data['review'] = np.select(cond, gb)

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  review
# 0               7.4             0.700         0.00  ...      9.4        5     Bad
# 1               7.8             0.880         0.00  ...      9.8        5     Bad
# 2               7.8             0.760         0.04  ...      9.8        5     Bad
# 3              11.2             0.280         0.56  ...      9.8        6     Bad
# 4               7.4             0.700         0.00  ...      9.4        5     Bad
# ...             ...               ...          ...  ...      ...      ...     ...
# 1594            6.2             0.600         0.08  ...     10.5        5     Bad
# 1595            5.9             0.550         0.10  ...     11.2        6     Bad
# 1596            6.3             0.510         0.13  ...     11.0        6     Bad
# 1597            5.9             0.645         0.12  ...     10.2        5     Bad
# ...

# %%
data.iloc[300:350, :]
# Out:
#      fixed acidity  volatile acidity  citric acid  ...  alcohol  quality  review
# 300            7.5             0.530         0.06  ...     10.7        6     Bad
# 301           11.1             0.180         0.48  ...     10.1        6     Bad
# 302            8.3             0.705         0.12  ...     10.0        5     Bad
# 303            7.4             0.670         0.12  ...      9.5        5     Bad
# 304            8.4             0.650         0.60  ...      9.2        5     Bad
# 305           10.3             0.530         0.48  ...      9.3        6     Bad
# 306            7.6             0.620         0.32  ...      9.4        5     Bad
# 307           10.3             0.410         0.42  ...      9.5        6     Bad
# 308           10.3             0.430         0.44  ...      9.5        6     Bad
# 309            7.4             0.290         0.38  ...      9.5        6     Bad
# 310           10.3             0.530         0.48  ...      9.3        6     Bad
# ...
